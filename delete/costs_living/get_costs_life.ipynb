# %%
import json
import pandas as pd

# %%
f = open('results.json')
data = json.load(f)

# %%
df = pd.DataFrame()
for city in data['Netherlands']['child'].keys():
    try:
        for key in data['Netherlands']['child'][city].keys():
            ericson = (pd.DataFrame(data['Netherlands']['child']['Voorburg'][key]))
            ericson['city'] = city
            ericson['key'] = key
            df = pd.concat([ericson,df],0)
    except:
        pass
# Out:
# <ipython-input-3-8c094eec4f42>:8: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   df = pd.concat([ericson,df],0)

# %%
df = df.reset_index(drop=True)
df.columns = ['situation', 'price', 'del', 'city', 'key']
df=df.drop(['del'],1)
# Out:
# <ipython-input-4-dacc947e4236>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df=df.drop(['del'],1)

# %%
df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].str.replace('€', '')
df['price'] = df['price'].astype('float')
df['key'] = df['key'].str.replace('\n\n', '')

# %%
df[(df['city']=='Rotterdam')]
# Out:
#                                               situation     price       city  \
# 1155            Average Monthly Net Salary (After Tax)    1550.50  Rotterdam
# 1156  Mortgage Interest Rate in Percentages (%), Yea...      1.98  Rotterdam
# 1157  Price per Square Meter to Buy Apartment in Cit...   3250.00  Rotterdam
# 1158  Price per Square Meter to Buy Apartment Outsid...   1743.50  Rotterdam
# 1159              Apartment (1 bedroom) in City Centre    1043.33  Rotterdam
# 1160           Apartment (1 bedroom) Outside of Centre     883.33  Rotterdam
# 1161             Apartment (3 bedrooms) in City Centre    1866.67  Rotterdam
# 1162          Apartment (3 bedrooms) Outside of Centre    1633.33  Rotterdam
# 1163            1 Pair of Jeans (Levis 501 Or Similar)      65.00  Rotterdam
# 1164  1 Summer Dress in a Chain Store (Zara, H&M, ...)      65.00  Rotterdam
# 1165          1 Pair of Nike Running Shoes (Mid-Range)      72.50  Rotterdam
# 1166              1 Pair of Men Leather Business Shoes     104.28  Rotterdam
# 1167  Preschool (or Kindergarten), Full Day, Private...   2980.00  Rotterdam
# 1168  International Primary School, Yearly for 1 Child   16500.00  Rotterdam
# 1169             Fitness Club, Monthly Fee for 1 Adult      50.83  Rotterdam
# 1170             Tennis Court Rent (1 Hour on Weekend)      18.00  Rotterdam
# 1171             Cinema, International Release, 1 Seat      13.25  Rotterdam
# 1172  Basic (Electricity, Heating, Cooling, Water, G...    198.00  Rotterdam
# 1173  1 min. of Prepaid Mobile Tariff Local (No Disc...      0.35  Rotterdam
# 1174  Internet (60 Mbps or More, Unlimited Data, Cab...     47.90  Rotterdam
# 1175                  One-way Ticket (Local Transport)       3.25  Rotterdam
# 1176                      Monthly Pass (Regular Price)      90.00  Rotterdam
# 1177                        Taxi Start (Normal Tariff)       4.00  Rotterdam
# 1178                          Taxi 1km (Normal Tariff)       2.50  Rotterdam
# 1179                Taxi 1hour Waiting (Normal Tariff)      44.92  Rotterdam
# 1180                                Gasoline (1 liter)       1.65  Rotterdam
# 1181  Volkswagen Golf 1.4 90 KW Trendline (Or Equiva...  29653.00  Rotterdam
# 1182  Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equ...  38965.00  Rotterdam
# 1183                         Milk (regular), (1 liter)       0.90  Rotterdam
# 1184                  Loaf of Fresh White Bread (500g)       1.20  Rotterdam
# 1185                               Rice (white), (1kg)       3.00  Rotterdam
# 1186                               Eggs (regular) (12)       3.80  Rotterdam
# 1187                                Local Cheese (1kg)      14.00  Rotterdam
# 1188                             Chicken Fillets (1kg)       7.75  Rotterdam
# 1189  Beef Round (1kg) (or Equivalent Back Leg Red M...     12.00  Rotterdam
# 1190                                      Apples (1kg)       3.00  Rotterdam
